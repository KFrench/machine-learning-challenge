# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
new_df=df.drop(columns=["koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec"])
new_df
# Out:
#      koi_disposition  koi_period  koi_period_err1  koi_period_err2  \
# 0          CONFIRMED   54.418383     2.479000e-04    -2.479000e-04
# 1     FALSE POSITIVE   19.899140     1.490000e-05    -1.490000e-05
# 2     FALSE POSITIVE    1.736952     2.630000e-07    -2.630000e-07
# 3          CONFIRMED    2.525592     3.760000e-06    -3.760000e-06
# 4          CONFIRMED    4.134435     1.050000e-05    -1.050000e-05
# ...              ...         ...              ...              ...
# 6986  FALSE POSITIVE    8.589871     1.846000e-04    -1.846000e-04
# 6987  FALSE POSITIVE    0.527699     1.160000e-07    -1.160000e-07
# 6988       CANDIDATE    1.739849     1.780000e-05    -1.780000e-05
# 6989  FALSE POSITIVE    0.681402     2.430000e-06    -2.430000e-06
# 6990  FALSE POSITIVE    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0      162.513840          0.003520         -0.003520       0.586
# ...

# %%
drop_list=["koi_period_err1", "koi_period_err2","koi_time0bk_err1","koi_time0bk_err2","koi_time0bk_err1","koi_time0bk_err2","koi_impact_err1","koi_impact_err2","koi_duration_err1","koi_duration_err2","koi_depth_err1","koi_depth_err2","koi_prad_err1","koi_prad_err2", "koi_insol_err1", "koi_insol_err2","koi_steff_err1", "koi_steff_err2","koi_slogg_err1","koi_slogg_err2", "koi_srad_err1","koi_srad_err2","koi_tce_plnt_num"]
new2_df = new_df.drop(drop_list, axis=1)

# %%
new2_df["koi_disposition"].value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
new3_df=new2_df[(new2_df["koi_disposition"] == "CONFIRMED")|(new2_df["koi_disposition"] == "FALSE POSITIVE")]
new3_df
# Out:
#      koi_disposition  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0          CONFIRMED   54.418383   162.513840       0.586       4.50700
# 1     FALSE POSITIVE   19.899140   175.850252       0.969       1.78220
# 2     FALSE POSITIVE    1.736952   170.307565       1.276       2.40641
# 3          CONFIRMED    2.525592   171.595550       0.701       1.65450
# 4          CONFIRMED    4.134435   172.979370       0.762       3.14020
# ...              ...         ...          ...         ...           ...
# 6983  FALSE POSITIVE   21.513523   132.335600       2.441      77.98300
# 6986  FALSE POSITIVE    8.589871   132.016100       0.765       4.80600
# 6987  FALSE POSITIVE    0.527699   131.705093       1.252       3.22210
# 6989  FALSE POSITIVE    0.681402   132.181750       0.147       0.86500
# 6990  FALSE POSITIVE    4.856035   135.993300       0.134       3.07800
#
#       koi_depth  koi_prad  koi_teq  koi_insol  koi_model_snr  koi_steff  \
# ...

# %%
new3_df.to_csv("Resources/filtered_planets.csv",index=False)

# %%
planets_filtered = pd.read_csv('Resources/filtered_planets.csv')
print(planets_filtered.shape)
planets_filtered.head()
# Out:
# (5304, 16)
#   koi_disposition  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0       CONFIRMED   54.418383   162.513840       0.586       4.50700
# 1  FALSE POSITIVE   19.899140   175.850252       0.969       1.78220
# 2  FALSE POSITIVE    1.736952   170.307565       1.276       2.40641
# 3       CONFIRMED    2.525592   171.595550       0.701       1.65450
# 4       CONFIRMED    4.134435   172.979370       0.762       3.14020
#
#    koi_depth  koi_prad  koi_teq  koi_insol  koi_model_snr  koi_steff  \
# 0      874.8      2.83      443       9.11           25.8       5455
# 1    10829.0     14.60      638      39.30           76.3       5853
# 2     8079.2     33.46     1395     891.96          505.6       5805
# 3      603.3      2.75     1406     926.16           40.9       6031
# 4      686.0      2.77     1160     427.65           40.2       6046
#
#    koi_slogg  koi_srad         ra        dec  koi_kepmag
# 0      4.467     0.927  291.93423  48.141651      15.347
# ...

# %%
null_counts = planets_filtered.isnull().sum()
print("Number of null values in each column:\n{}".format(null_counts))
# Out:
# Number of null values in each column:
# koi_disposition    0
# koi_period         0
# koi_time0bk        0
# koi_impact         0
# koi_duration       0
# koi_depth          0
# koi_prad           0
# koi_teq            0
# koi_insol          0
# koi_model_snr      0
# koi_steff          0
# koi_slogg          0
# koi_srad           0
# ra                 0
# dec                0
# koi_kepmag         0
# dtype: int64

# %%
planets_filtered.dtypes.value_counts()
# Out:
# float64    13
# int64       2
# object      1
# dtype: int64

# %%
object_columns_df = planets_filtered.select_dtypes(include=['object'])
print(object_columns_df.iloc[0])
# Out:
# koi_disposition    CONFIRMED
# Name: 0, dtype: object

# %%
mapping_dict = {
"koi_disposition": {
"CONFIRMED": 1, "FALSE POSITIVE":0}}

# %%
planets_filtered = planets_filtered.replace(mapping_dict)
planets_filtered[['koi_disposition']].head()
# Out:
#    koi_disposition
# 0                1
# 1                0
# 2                0
# 3                1
# 4                1

# %%
planets_filtered.astype({'koi_disposition': 'int32'}).dtypes
# Out:
# koi_disposition      int32
# koi_period         float64
# koi_time0bk        float64
# koi_impact         float64
# koi_duration       float64
# koi_depth          float64
# koi_prad           float64
# koi_teq              int64
# koi_insol          float64
# koi_model_snr      float64
# koi_steff            int64
# koi_slogg          float64
# koi_srad           float64
# ra                 float64
# dec                float64
# koi_kepmag         float64
# dtype: object

# %%
planets_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5304 entries, 0 to 5303
# Data columns (total 16 columns):
# koi_disposition    5304 non-null int64
# koi_period         5304 non-null float64
# koi_time0bk        5304 non-null float64
# koi_impact         5304 non-null float64
# koi_duration       5304 non-null float64
# koi_depth          5304 non-null float64
# koi_prad           5304 non-null float64
# koi_teq            5304 non-null int64
# koi_insol          5304 non-null float64
# koi_model_snr      5304 non-null float64
# koi_steff          5304 non-null int64
# koi_slogg          5304 non-null float64
# koi_srad           5304 non-null float64
# ra                 5304 non-null float64
# dec                5304 non-null float64
# koi_kepmag         5304 non-null float64
# dtypes: float64(13), int64(3)
# memory usage: 663.1 KB

# %%
planets_filtered.to_csv("Resources/cleaned_planets.csv",index=False)

# %%
final_plants = pd.read_csv('Resources/cleaned_planets.csv')
final_plants
# Out:
#       koi_disposition  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0                   1   54.418383   162.513840       0.586       4.50700
# 1                   0   19.899140   175.850252       0.969       1.78220
# 2                   0    1.736952   170.307565       1.276       2.40641
# 3                   1    2.525592   171.595550       0.701       1.65450
# 4                   1    4.134435   172.979370       0.762       3.14020
# ...               ...         ...          ...         ...           ...
# 5299                0   21.513523   132.335600       2.441      77.98300
# 5300                0    8.589871   132.016100       0.765       4.80600
# 5301                0    0.527699   131.705093       1.252       3.22210
# 5302                0    0.681402   132.181750       0.147       0.86500
# 5303                0    4.856035   135.993300       0.134       3.07800
#
#       koi_depth  koi_prad  koi_teq  koi_insol  koi_model_snr  koi_steff  \
# ...

# %%
X=final_plants["koi_impact"].values.reshape(5304, 1)
y=final_plants["koi_disposition"].values.reshape(5304, 1)

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (5304, 1) (5304, 1)

# %%
plt.scatter(X, y)
plt.xlabel("Koi_impact")
plt.ylabel("koi_disposition")
# Out:
# Text(0, 0.5, 'koi_disposition')

# %%
from sklearn.model_selection import train_test_split

### BEGIN SOLUTION

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

from sklearn.metrics import mean_squared_error, r2_score

### BEGIN SOLUTION

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 0.39369727495044143
# R-squared (R2 ): -0.7541424638853655

# %%
model.score(X_test, y_test)
# Out:
# -0.7541424638853655
